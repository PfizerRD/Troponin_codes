# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
import sys
import time
import scipy.io as io
import os
from os import listdir
import glob
import time
import multiprocessing
from joblib import Parallel, delayed
import shutil
from scipy.signal import find_peaks
import csv

def estimateTimePoints(length,speed,peaks,leftBound,rightBound,th = 0.7,register=0):
    A_list = []
    B_list = []
    C_list = []
    D_list = []
    E_list = []
    F_list = []
    J_list = []
    I_list = []
   
    for ii in range(len(leftBound)):
        if leftBound[ii]<5 or rightBound[ii]>len(speed):
            continue
        maxV = np.max(speed[leftBound[ii]:rightBound[ii]])
        minV = np.min(speed[leftBound[ii]:rightBound[ii]])       
        pos_ind = peaks[ii]+np.argmax(speed[peaks[ii]:rightBound[ii]])
        neg_ind = leftBound[ii]+np.argmin(speed[leftBound[ii]:peaks[ii]])
        A_ind = leftBound[ii]+np.argmin(np.abs(minV*th-speed[leftBound[ii]:neg_ind]))
        C_ind = neg_ind+np.argmin(np.abs(minV*th-speed[neg_ind:pos_ind]))
        
        D_ind = neg_ind+np.argmin(np.abs(maxV*th-speed[neg_ind:pos_ind]))
        F_ind = pos_ind+np.argmin(np.abs(maxV*th-speed[pos_ind:rightBound[ii]]))
        
        length_min = length[peaks[ii]]
        length_base = np.percentile(length[leftBound[ii]:rightBound[ii]],95)
        
        dH = length_base-length_min
        
        I_ind = peaks[ii]+np.argmin(np.abs(dH*th-(length[peaks[ii]:rightBound[ii]]-length_min)))
        
        A_list.append(A_ind)
        B_list.append(neg_ind)
        C_list.append(C_ind)
        D_list.append(D_ind)
        E_list.append(pos_ind)
        F_list.append(F_ind)
        J_list.append(peaks[ii])
        I_list.append(I_ind)
        
    
    As = np.array(A_list)
    Bs = np.array(B_list)
    Cs = np.array(C_list)
    Ds = np.array(D_list)
    Es = np.array(E_list)
    Fs = np.array(F_list)
    Js = np.array(J_list)
    Is = np.array(I_list)
    
    As = As[:-1]
    Bs = Bs[:-1]
    Cs = Cs[:-1]
    Ds = Ds[:-1]
    Es = Es[:-1]
    Fs = Fs[:-1]
    Js = Js[:-1]
    Is = Is[:-1]
    
    
    ###if len(As):
    if 0:
        fig, (ax1,ax2) = plt.subplots(2,1)
        ###plt.rcParams['figure.figsize'] = [28, 10]
        ###plt.subplot(211)
        ax1.plot(length)
        ax1.plot(Is,length[Is], "x")
        ax1.plot(Is,length[Is-1], "d")
        ax1.plot(Is,length[Is+1], "d")
        ax1.plot(Js,length[Js], "o")
      
        ax1.set_title('NORMALIZED LENGTH CHANGE')
        ###plt.subplot(212)
        ax2.plot(speed)
        ax2.plot(As,speed[As], "x")
        ax2.plot(Bs,speed[Bs], "x")
        ax2.plot(Cs,speed[Cs], "x")
        ax2.plot(Ds,speed[Ds], "D")
        ax2.plot(Es,speed[Es], "D")
        ax2.plot(Fs,speed[Fs], "D")
        ax2.set_title('NORMALIZED SPEED'+ str(th))
        ###if register:
        ####     displayFigName5 = dirName +'\\' + videoFileName[:-4]+"_segmentation_cell_"+str(tag)+"_quantification_register_part5_th_"+str(round(th*100)) +".jpg"
        ###else:
        ###    displayFigName5 = dirName +'\\' + videoFileName[:-4]+"_segmentation_cell_"+str(tag)+"_quantification_part5_th_"+str(round(th*100)) +".jpg"
        print("point detection:")
        print(displayFigName5)
        fig.savefig(displayFigName5)
        fig.clf()
        plt.close(fig)
       
    return As,Bs,Cs,Ds,Es,Fs,Js,Is 
   
def draw_trace(length, speed, rootOutputDir,subfolder,cellTag,As,Bs,Cs,Ds,Es,Fs,Js,Is):
    fig,ax=plt.subplots(2,1,sharex=True,figsize=(16,10))

    ax[0].plot(length)
    ax[0].set_title('LENGTH CHANGE',fontsize=20)
    ax[1].plot(speed)
    ax[1].set_title('SPEED',fontsize=20) 
        
    if len(As):
        ax[0].plot(Is,length[Is], "x",markersize=10)
        ax[0].plot(Is,length[Is-1], "d",markersize=8)
        ax[0].plot(Is,length[Is+1], "d",markersize=8)
        ax[0].plot(Js,length[Js], "o",markersize=10)
   
        ax[1].plot(As,speed[As], "x",markersize=8)
        ax[1].plot(Bs,speed[Bs], "x",markersize=8)
        ax[1].plot(Cs,speed[Cs], "x",markersize=8)
        ax[1].plot(Ds,speed[Ds], "D",markersize=8)
        ax[1].plot(Es,speed[Es], "D",markersize=8)
        ax[1].plot(Fs,speed[Fs], "D",markersize=8)
    
    
    displayFigName = rootOutputDir+"\\"+'trace_'+subfolder+"_cell_"+cellTag+'.jpg'
    fig.savefig(displayFigName)
    fig.clf()
    plt.close(fig)
    
def csv_results_output(csvOutputName,subFolder,tag,length,speed,As,Bs,Cs,Ds,Es,Fs,Js,Is,initial=1):
    
    num_periods = min(len(As),len(Bs),len(Cs),len(Ds),len(Es),len(Fs),len(Js),len(Is))
    frameNum = len(length)
    
    if initial:
        fout = open(csvOutputName, 'w', newline='')

        writer = csv.writer(fout)
        writer.writerow( ('subFolder','cellTag', 'A_frame', 'B_frame','C_frame','D_frame','E_frame','F_frame','J_frame','I_frame',
                          'A_value','A_value_minus','A_value_plus','B_value','B_Value_minus','B_value_plus',
                          'C_value','C_value_minus','C_value_plus','D_value','D_Value_minus','D_value_plus',
                          'E_value','E_value_minus','E_value_plus','F_value','F_Value_minus','F_value_plus',
                          'J_value','J_value_minus','J_value_plus','I_value','I_Value_minus','I_value_plus','total_frame_num'))
    else:
        fout = open(csvOutputName, 'a', newline='')

        writer = csv.writer(fout)
    
    for jj in range(num_periods):
        writer.writerow((subFolder, tag, As[jj], Bs[jj], Cs[jj], Ds[jj], Es[jj], Fs[jj], Js[jj],Is[jj],
                           speed[As[jj]],speed[As[jj]-1],speed[As[jj]+1],
                           speed[Bs[jj]],speed[Bs[jj]-1],speed[Bs[jj]+1],
                           speed[Cs[jj]],speed[Cs[jj]-1],speed[Cs[jj]+1],
                           speed[Ds[jj]],speed[Ds[jj]-1],speed[Ds[jj]+1],
                           speed[Es[jj]],speed[Es[jj]-1],speed[Es[jj]+1],
                           speed[Fs[jj]],speed[Fs[jj]-1],speed[Fs[jj]+1],
                           length[Js[jj]],length[Js[jj]-1],length[Js[jj]+1],
                           length[Is[jj]],length[Is[jj]-1],length[Is[jj]+1],frameNum))
    fout.flush()
    fout.close()

def post_analysis_npz_file(inputSubfolder,rootOutputDir,distance=80,half_width = 70,ds=1):
    print("src folder: " + inputSubfolder)
   
    (inputDirName,inputFolderName) = os.path.split(inputSubfolder)
    ###print("inputDirName: " + inputDirName)
    print("inputFolderName: " + inputFolderName)

    csvOutputFileName = rootOutputDir+"\\"+ "contractivity_relaxation_features_reg_relax_percent_"+inputFolderName+".csv"
    csv_results_output(csvOutputFileName,inputFolderName,'-1','','',[],[],[],[],[],[],[],[],initial = 1)
    npzFileNames = glob.glob(inputSubfolder+"/*.npz")
    ###print(npzFileNames)
    ###print(len(cellFolderNames))
    for ii in range(len(npzFileNames)):
        npzFileName = npzFileNames[ii]
        ###print(npzFileName)
        cellTag0 = npzFileName.split('_cell_')[1]
        cellTag = cellTag0.split('.npz')[0]
        ###print('cellTag: ' + cellTag)
        npzfile=np.load(npzFileName)
        length = npzfile['length']
        
        length = length[::ds]

        speed = np.gradient(length)
        maxV = np.max(speed)
        minV = np.min(speed)

        force = np.max(length)-length
        maxForce = np.max(force)

        peaks, _ = find_peaks(force, height=maxForce*0.3,distance=distance)

        ###half_width = half_width # related to sample freqency
        leftBound = peaks-half_width
        rightBound = peaks+half_width
        try:
            As,Bs,Cs,Ds,Es,Fs,Js,Is  = estimateTimePoints(length,speed,peaks,leftBound,rightBound)
        except:
            continue
        
        csv_results_output(csvOutputFileName,inputFolderName,cellTag,length,speed,As,Bs,Cs,Ds,Es,Fs,Js,Is,initial=0)
        
        draw_trace(length, speed, rootOutputDir,inputFolderName,cellTag,As,Bs,Cs,Ds,Es,Fs,Js,Is)
        ###segImgName=cellFolderNames[ii]+"\\frame_0000.jpg"
        ###traceFigName0 = cellFolderNames[ii].split("_registered")[0]
        ###cellTagName = traceFigName0.split("_cell_")[1]
        ###traceFigName = traceFigName0+'_quantification_register_part5_th_70.jpg'
        ###outputTraceFigName = rootOutputDir +"\\" + inputFolderName + "_cell_" +cellTagName+"_QC.jpg"

        ###if os.path.exists(traceFigName):
        ###    segImg = cv2.imread(segImgName)
        ###    traceFig = cv2.imread(traceFigName)
          
        ###    outputFig = np.concatenate((segImg,traceFig), axis=0)
        ###    cv2.imwrite(outputTraceFigName, outputFig)

# %%
rootInputDir = r'Z:\pangj05\TROPONIN2021\20210616DataSetAnalysis\Pairwise\T0_BeforeDosing_DMSO'
rootOutputDir = r'Z:\pangj05\TROPONIN2021\20210616DataSetAnalysis\Pairwise\detailed_post_processing\T0_DMSO'

inputSubfolders = [os.path.join(rootInputDir, o) for o in os.listdir(rootInputDir) if os.path.isdir(os.path.join(rootInputDir,o))]

inputSubfolders = sorted(inputSubfolders)
if not os.path.isdir(rootOutputDir):
    print('The SUBFOLDER directory is not present. Creating a new one..')
    os.mkdir(rootOutputDir)

distance = 80 ## freq=200
half_width = 70 ## freq = 200
ds =1
tic = time.time()
for ii in range(len(inputSubfolders)):
###for ii in range(1):
    post_analysis_npz_file(inputSubfolders[ii],rootOutputDir,distance=distance,half_width = half_width,ds=ds)
    ###post_analysis_npz_file(inputSubfolders[ii],rootOutputDir)
toc = time.time()
print('total time is: ' + str(toc-tic))
# Out:
# src folder: Z:\pangj05\TROPONIN2021\20210616DataSetAnalysis\Pairwise\T0_BeforeDosing_DMSO\T0_BeforeDosing_DMSO_s01
# inputFolderName: T0_BeforeDosing_DMSO_s01
# src folder: Z:\pangj05\TROPONIN2021\20210616DataSetAnalysis\Pairwise\T0_BeforeDosing_DMSO\T0_BeforeDosing_DMSO_s02
# inputFolderName: T0_BeforeDosing_DMSO_s02
# src folder: Z:\pangj05\TROPONIN2021\20210616DataSetAnalysis\Pairwise\T0_BeforeDosing_DMSO\T0_BeforeDosing_DMSO_s03
# inputFolderName: T0_BeforeDosing_DMSO_s03
# src folder: Z:\pangj05\TROPONIN2021\20210616DataSetAnalysis\Pairwise\T0_BeforeDosing_DMSO\T0_BeforeDosing_DMSO_s04
# inputFolderName: T0_BeforeDosing_DMSO_s04
# src folder: Z:\pangj05\TROPONIN2021\20210616DataSetAnalysis\Pairwise\T0_BeforeDosing_DMSO\T0_BeforeDosing_DMSO_s05
# inputFolderName: T0_BeforeDosing_DMSO_s05
# src folder: Z:\pangj05\TROPONIN2021\20210616DataSetAnalysis\Pairwise\T0_BeforeDosing_DMSO\T0_BeforeDosing_DMSO_s06
# inputFolderName: T0_BeforeDosing_DMSO_s06
# src folder: Z:\pangj05\TROPONIN2021\20210616DataSetAnalysis\Pairwise\T0_BeforeDosing_DMSO\T0_BeforeDosing_DMSO_s07
# inputFolderName: T0_BeforeDosing_DMSO_s07
# src folder: Z:\pangj05\TROPONIN2021\20210616DataSetAnalysis\Pairwise\T0_BeforeDosing_DMSO\T0_BeforeDosing_DMSO_s08
# inputFolderName: T0_BeforeDosing_DMSO_s08
# src folder: Z:\pangj05\TROPONIN2021\20210616DataSetAnalysis\Pairwise\T0_BeforeDosing_DMSO\T0_BeforeDosing_DMSO_s09
# inputFolderName: T0_BeforeDosing_DMSO_s09
# src folder: Z:\pangj05\TROPONIN2021\20210616DataSetAnalysis\Pairwise\T0_BeforeDosing_DMSO\T0_BeforeDosing_DMSO_s10
# inputFolderName: T0_BeforeDosing_DMSO_s10
# src folder: Z:\pangj05\TROPONIN2021\20210616DataSetAnalysis\Pairwise\T0_BeforeDosing_DMSO\T0_BeforeDosing_DMSO_s11
# inputFolderName: T0_BeforeDosing_DMSO_s11
# src folder: Z:\pangj05\TROPONIN2021\20210616DataSetAnalysis\Pairwise\T0_BeforeDosing_DMSO\T0_BeforeDosing_DMSO_s12
# inputFolderName: T0_BeforeDosing_DMSO_s12
# src folder: Z:\pangj05\TROPONIN2021\20210616DataSetAnalysis\Pairwise\T0_BeforeDosing_DMSO\T0_BeforeDosing_DMSO_s13
# inputFolderName: T0_BeforeDosing_DMSO_s13
# src folder: Z:\pangj05\TROPONIN2021\20210616DataSetAnalysis\Pairwise\T0_BeforeDosing_DMSO\T0_BeforeDosing_DMSO_s14
# inputFolderName: T0_BeforeDosing_DMSO_s14
# src folder: Z:\pangj05\TROPONIN2021\20210616DataSetAnalysis\Pairwise\T0_BeforeDosing_DMSO\T0_BeforeDosing_DMSO_s15
# inputFolderName: T0_BeforeDosing_DMSO_s15
# src folder: Z:\pangj05\TROPONIN2021\20210616DataSetAnalysis\Pairwise\T0_BeforeDosing_DMSO\T0_BeforeDosing_DMSO_s16
# inputFolderName: T0_BeforeDosing_DMSO_s16
# src folder: Z:\pangj05\TROPONIN2021\20210616DataSetAnalysis\Pairwise\T0_BeforeDosing_DMSO\T0_BeforeDosing_DMSO_s17
# inputFolderName: T0_BeforeDosing_DMSO_s17
# src folder: Z:\pangj05\TROPONIN2021\20210616DataSetAnalysis\Pairwise\T0_BeforeDosing_DMSO\T0_BeforeDosing_DMSO_s18
# inputFolderName: T0_BeforeDosing_DMSO_s18
# src folder: Z:\pangj05\TROPONIN2021\20210616DataSetAnalysis\Pairwise\T0_BeforeDosing_DMSO\T0_BeforeDosing_DMSO_s19
# inputFolderName: T0_BeforeDosing_DMSO_s19
# src folder: Z:\pangj05\TROPONIN2021\20210616DataSetAnalysis\Pairwise\T0_BeforeDosing_DMSO\T0_BeforeDosing_DMSO_s20
# inputFolderName: T0_BeforeDosing_DMSO_s20
# src folder: Z:\pangj05\TROPONIN2021\20210616DataSetAnalysis\Pairwise\T0_BeforeDosing_DMSO\T0_BeforeDosing_DMSO_s21
# inputFolderName: T0_BeforeDosing_DMSO_s21
# src folder: Z:\pangj05\TROPONIN2021\20210616DataSetAnalysis\Pairwise\T0_BeforeDosing_DMSO\T0_BeforeDosing_DMSO_s22
# inputFolderName: T0_BeforeDosing_DMSO_s22
# src folder: Z:\pangj05\TROPONIN2021\20210616DataSetAnalysis\Pairwise\T0_BeforeDosing_DMSO\T0_BeforeDosing_DMSO_s23
# inputFolderName: T0_BeforeDosing_DMSO_s23
# src folder: Z:\pangj05\TROPONIN2021\20210616DataSetAnalysis\Pairwise\T0_BeforeDosing_DMSO\T0_BeforeDosing_DMSO_s24
# inputFolderName: T0_BeforeDosing_DMSO_s24
# src folder: Z:\pangj05\TROPONIN2021\20210616DataSetAnalysis\Pairwise\T0_BeforeDosing_DMSO\T0_BeforeDosing_DMSO_s25
# inputFolderName: T0_BeforeDosing_DMSO_s25
# src folder: Z:\pangj05\TROPONIN2021\20210616DataSetAnalysis\Pairwise\T0_BeforeDosing_DMSO\T0_BeforeDosing_DMSO_s26
# inputFolderName: T0_BeforeDosing_DMSO_s26
# src folder: Z:\pangj05\TROPONIN2021\20210616DataSetAnalysis\Pairwise\T0_BeforeDosing_DMSO\T0_BeforeDosing_DMSO_s27
# inputFolderName: T0_BeforeDosing_DMSO_s27
# src folder: Z:\pangj05\TROPONIN2021\20210616DataSetAnalysis\Pairwise\T0_BeforeDosing_DMSO\T0_BeforeDosing_DMSO_s28
# inputFolderName: T0_BeforeDosing_DMSO_s28
# src folder: Z:\pangj05\TROPONIN2021\20210616DataSetAnalysis\Pairwise\T0_BeforeDosing_DMSO\T0_BeforeDosing_DMSO_s29
# inputFolderName: T0_BeforeDosing_DMSO_s29
# src folder: Z:\pangj05\TROPONIN2021\20210616DataSetAnalysis\Pairwise\T0_BeforeDosing_DMSO\T0_BeforeDosing_DMSO_s30
# inputFolderName: T0_BeforeDosing_DMSO_s30
# src folder: Z:\pangj05\TROPONIN2021\20210616DataSetAnalysis\Pairwise\T0_BeforeDosing_DMSO\T0_BeforeDosing_DMSO_s31
# inputFolderName: T0_BeforeDosing_DMSO_s31
# src folder: Z:\pangj05\TROPONIN2021\20210616DataSetAnalysis\Pairwise\T0_BeforeDosing_DMSO\T0_BeforeDosing_DMSO_s32
# inputFolderName: T0_BeforeDosing_DMSO_s32
# src folder: Z:\pangj05\TROPONIN2021\20210616DataSetAnalysis\Pairwise\T0_BeforeDosing_DMSO\T0_BeforeDosing_DMSO_s33
# inputFolderName: T0_BeforeDosing_DMSO_s33
# src folder: Z:\pangj05\TROPONIN2021\20210616DataSetAnalysis\Pairwise\T0_BeforeDosing_DMSO\T0_BeforeDosing_DMSO_s34
# inputFolderName: T0_BeforeDosing_DMSO_s34
# src folder: Z:\pangj05\TROPONIN2021\20210616DataSetAnalysis\Pairwise\T0_BeforeDosing_DMSO\T0_BeforeDosing_DMSO_s35
# inputFolderName: T0_BeforeDosing_DMSO_s35
# src folder: Z:\pangj05\TROPONIN2021\20210616DataSetAnalysis\Pairwise\T0_BeforeDosing_DMSO\T0_BeforeDosing_DMSO_s36
# inputFolderName: T0_BeforeDosing_DMSO_s36
# total time is: 304.71385192871094
